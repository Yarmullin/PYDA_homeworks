# %%
import pandas as pd
import numpy as np
from scipy import stats as st
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
import seaborn as sns

# %% [markdown]
# #### 1. Загрузите файл HR.csv в pandas dataframe

# %%
df = pd.read_csv('HR.csv')
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   department             14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %% [markdown]
# #### 2. Рассчитайте основные статистики для переменных
# (среднее,медиана,мода,мин/макс,сред.отклонение).

# %%
describe= df.describe().T #все, кроме моды
names = df.columns.values.tolist() #здесь и далее алгоритм добавления моды в describe
dict_modes = {}
for v in names:
    dict_modes[v] = df[v].mode()[0]
modes = pd.DataFrame.from_dict(dict_modes, orient='index')
modes.rename(columns = {0:'mode'}, inplace = True)
describe.join(modes, how='left').T
# Out:
#       satisfaction_level last_evaluation number_project average_montly_hours  \
# count              14999           14999          14999                14999
# mean            0.612834        0.716102        3.80305               201.05
# std             0.248631        0.171169        1.23259              49.9431
# min                 0.09            0.36              2                   96
# 25%                 0.44            0.56              3                  156
# 50%                 0.64            0.72              4                  200
# 75%                 0.82            0.87              5                  245
# max                    1               1              7                  310
# mode                 0.1            0.55              4                  135
#
#       time_spend_company Work_accident      left promotion_last_5years
# count              14999         14999     14999                 14999
# ...

# %% [markdown]
# #### 3. Рассчитайте и визуализировать корреляционную матрицу для количественных переменных.
# Определите две самые скоррелированные и две наименее
# скоррелированные переменные.

# %%
corr = df.corr()
corr.rename(columns={'promotion_last_5years': 'last_5years'}, inplace=True)
corr
# Out:
#                        satisfaction_level  last_evaluation  number_project  \
# satisfaction_level               1.000000         0.105021       -0.142970
# last_evaluation                  0.105021         1.000000        0.349333
# number_project                  -0.142970         0.349333        1.000000
# average_montly_hours            -0.020048         0.339742        0.417211
# time_spend_company              -0.100866         0.131591        0.196786
# Work_accident                    0.058697        -0.007104       -0.004741
# left                            -0.388375         0.006567        0.023787
# promotion_last_5years            0.025605        -0.008684       -0.006064
#
#                        average_montly_hours  time_spend_company  \
# satisfaction_level                -0.020048           -0.100866
# last_evaluation                    0.339742            0.131591
# number_project                     0.417211            0.196786
# ...

# %%
ax = sns.heatmap(corr)

# %%
corr_max = df.corr().abs()
corr_max.replace([1], [0], inplace=True)
corr_max
# Out:
#                        satisfaction_level  last_evaluation  number_project  \
# satisfaction_level               0.000000         0.105021        0.142970
# last_evaluation                  0.105021         0.000000        0.349333
# number_project                   0.142970         0.349333        0.000000
# average_montly_hours             0.020048         0.339742        0.417211
# time_spend_company               0.100866         0.131591        0.196786
# Work_accident                    0.058697         0.007104        0.004741
# left                             0.388375         0.006567        0.023787
# promotion_last_5years            0.025605         0.008684        0.006064
#
#                        average_montly_hours  time_spend_company  \
# satisfaction_level                 0.020048            0.100866
# last_evaluation                    0.339742            0.131591
# number_project                     0.417211            0.196786
# ...

# %%
# ищем 2 самые скоррелированные величины, берем матрицу по модулю, т.к. возможна и обратная корреляция
indexes = pd.DataFrame(corr_max.idxmax())
indexes.rename(columns = {0:'indexes2'}, inplace=True)
values = pd.DataFrame(corr_max.max())
values.rename(columns = {0:'values'}, inplace=True)
max_corr = indexes.join(values)
max_corr.sort_values('values', ascending=False)
# Out:
#                                    indexes2    values
# number_project         average_montly_hours  0.417211
# average_montly_hours         number_project  0.417211
# satisfaction_level                     left  0.388375
# left                     satisfaction_level  0.388375
# last_evaluation              number_project  0.349333
# time_spend_company           number_project  0.196786
# Work_accident                          left  0.154622
# promotion_last_5years    time_spend_company  0.067433

# %%
# прямая
corr = df.corr()
corr.replace([1], [0], inplace=True)
indexes2 = pd.DataFrame(corr.idxmax())
indexes2.rename(columns = {0:'indexes2'}, inplace=True)
values2 = pd.DataFrame(corr.max())
values2.rename(columns = {0:'values'}, inplace=True)
positive_corr = indexes2.join(values2)
positive_corr.sort_values('values', ascending=False)
# Out:
#                                    indexes2    values
# number_project         average_montly_hours  0.417211
# average_montly_hours         number_project  0.417211
# last_evaluation              number_project  0.349333
# time_spend_company           number_project  0.196786
# left                     time_spend_company  0.144822
# satisfaction_level          last_evaluation  0.105021
# promotion_last_5years    time_spend_company  0.067433
# Work_accident            satisfaction_level  0.058697

# %%
# обратная
corr_neg = df.corr()
indexes3 = pd.DataFrame(corr_neg.idxmin())
indexes3.rename(columns = {0:'indexes2'}, inplace=True)
values3 = pd.DataFrame(corr_neg.min())
values3.rename(columns = {0:'values'}, inplace=True)
negative_corr = indexes3.join(values3)
negative_corr.sort_values('values')
# Out:
#                                     indexes2    values
# satisfaction_level                      left -0.388375
# left                      satisfaction_level -0.388375
# Work_accident                           left -0.154622
# number_project            satisfaction_level -0.142970
# time_spend_company        satisfaction_level -0.100866
# promotion_last_5years                   left -0.061788
# average_montly_hours      satisfaction_level -0.020048
# last_evaluation        promotion_last_5years -0.008684

# %%
# ищем 2 слабоскоррелированные величины, берем матрицу по модулю, т.к. возможна и обратная корреляция
corr_min = df.corr().abs()
indexes1 = pd.DataFrame(corr_min.idxmin())
indexes1.rename(columns = {0:'indexes2'}, inplace=True)
values1 = pd.DataFrame(corr_min.min())
values1.rename(columns = {0:'values'}, inplace=True)
min_corr = indexes1.join(values1)
min_corr.sort_values('values')
# Out:
#                                     indexes2    values
# time_spend_company             Work_accident  0.002120
# Work_accident             time_spend_company  0.002120
# average_montly_hours   promotion_last_5years  0.003544
# promotion_last_5years   average_montly_hours  0.003544
# number_project                 Work_accident  0.004741
# last_evaluation                         left  0.006567
# left                         last_evaluation  0.006567
# satisfaction_level      average_montly_hours  0.020048

# %% [markdown]
# ### Выводы:
# 1. Наиболее скоррелированные величины в нашем датасете - это: количество проектов и среднее кол-во часов на рабочем месте. Корреляция прямая, т.е. чем больше проектов, тем чаще сотрудник проводит время на рабочем месте.
# 2. Наименее скоррелированные величины это: стаж работы и травматичность. То есть вероятность травмы возможна как у новичков, так и у опытных сотрудников.
# 3. Примечателен факт наличия сильной обратной корреляции между уровнем удовлетворенности работой и фактом увольнения сотрудника.

# %% [markdown]
# #### 4. Рассчитайте сколько сотрудников работает в каждом департаменте.

# %%
df_pivot = df.pivot_table(index = 'department', values = 'satisfaction_level',aggfunc = 'count', fill_value = 0, margins = True)
df_pivot.sort_values('satisfaction_level')
# Out:
#              satisfaction_level
# department
# management                  630
# hr                          739
# accounting                  767
# RandD                       787
# marketing                   858
# product_mng                 902
# IT                         1227
# support                    2229
# technical                  2720
# sales                      4140
# All                       14999

# %% [markdown]
# #### 5. Показать распределение сотрудников по зарплатам.

# %%
df_salary = df.pivot_table(index = 'salary', values = 'satisfaction_level',aggfunc = 'count', fill_value = 0, margins = True).sort_values('satisfaction_level')
df_salary_t = df_salary.T
names_l = df_salary_t.columns.values.tolist()
names_l.reverse()
del(names_l[0])
df_salary_p = pd.DataFrame()
for name in names_l:
    df_salary_p[name] = (df_salary_t[name]/df_salary_t['All'])*100
df_salary_p
# Out:
#                           low     medium      high
# satisfaction_level  48.776585  42.976198  8.247216

# %%
df_salary_p.plot(kind = 'bar', rot=45, stacked = True)

# %% [markdown]
# #### 6. Показать распределение сотрудников по зарплатам в каждом департаменте по отдельности

# %%
df_salary_dpt = df.pivot_table(index = 'department', columns = 'salary', values = 'satisfaction_level',aggfunc = 'count', fill_value = 0, margins = True)
names_lev = df_salary_dpt.columns.values.tolist()
names_lev.reverse()
df_salary_per = pd.DataFrame()
del(names_lev[0])
for name in names_lev:
    df_salary_per[name] = (df_salary_dpt[name]/df_salary_dpt['All'])*100
df_salary_per
# Out:
#                 medium        low       high
# department
# IT           43.602282  49.633252   6.764466
# RandD        47.268107  46.251588   6.480305
# accounting   43.676662  46.675359   9.647979
# hr           48.579161  45.331529   6.089310
# management   35.714286  28.571429  35.714286
# marketing    43.822844  46.853147   9.324009
# product_mng  42.461197  50.000000   7.538803
# sales        42.801932  50.700483   6.497585
# support      42.261104  51.413190   6.325707
# technical    42.169118  50.441176   7.389706
# All          42.976198  48.776585   8.247216

# %%
df_salary_per.plot(kind = 'bar', rot=45, stacked = True)

# %% [markdown]
# ### Выводы по распределению зп:
# В целом, по компании мы можем сказать, что 90% сотрудников считают свои заработки или средними или низкими.
# Если говорить в разрезе подразделений, то мы видим, что результаты отличаются - здесь распределение более равномерно, так же мы видим, что 70% сотрудников категоричны в своих суждениях: считают свои заработки или низкими, или высокими.

# %% [markdown]
# #### 7. Проверить гипотезу, что сотрудники с высоким окладом проводят на работе больше времени, чем сотрудники с низким окладом
#
# Гипотеза Н0: Сотрудники с высоким и низким окладами проводят одинаковое кол-во времени на работе.
#
# Гипотеза H1: Сотрудники с высоким и низким окладами проводят разное кол-во времени на работе.

# %%
df_low = df[df.salary == 'low']
df_high = df[df.salary == 'high']
alpha = 0.05
result = st.ttest_ind(df_low['average_montly_hours'], df_high['average_montly_hours'], equal_var=False)
print(result)
if (result.pvalue < alpha):
    print('Отвергаем нулевую гипотезу, у сотрудников разное кол-во времени на работе.')
else:
    print('Не отвергаем нулевую гипотезу, сотрудники с разными окладами проводят примерно одинаковое кол-во времени на работе.')
# Out:
# Ttest_indResult(statistic=0.7624331665385475, pvalue=0.4459045542257889)
# Не отвергаем нулевую гипотезу, сотрудники с разными окладами проводят примерно одинаковое кол-во времени на работе.

# %% [markdown]
# #### 8. Рассчитать следующие показатели среди уволившихся и не уволившихся сотрудников (по отдельности):
#
# ● Доля сотрудников с повышением за последние 5 лет
#
# ● Средняя степень удовлетворенности
#
# ● Среднее количество проектов

# %%
df_left = df[df.left == 1]
a = df_left[df_left.promotion_last_5years == 1].promotion_last_5years.sum()
b = df_left.promotion_last_5years.count()
promotion = a / b
mean_satisfaction = df_left.satisfaction_level.mean()
mean_projects = df_left.number_project.mean()
print('Показатели среди уволившихся:')
final = pd.DataFrame({'index':['share_of_promo', 'mean_satisfaction', 'mean_number_project'], 'values': [promotion, mean_satisfaction, mean_projects]})
final
# Out:
# Показатели среди уволившихся:
#                  index    values
# 0       share_of_promo  0.005321
# 1    mean_satisfaction  0.440098
# 2  mean_number_project  3.855503

# %%
df_right = df[df.left == 0]
a = df_right[df_right.promotion_last_5years == 1].promotion_last_5years.sum()
b = df_right.promotion_last_5years.count()
promotion = a / b
mean_satisfaction = df_right.satisfaction_level.mean()
mean_projects = df_right.number_project.mean()
print('Показатели среди действующих сотрудников:')
final = pd.DataFrame({'index':['share_of_promo', 'mean_satisfaction', 'mean_number_project'], 'values': [promotion, mean_satisfaction, mean_projects]})
final
# Out:
# Показатели среди действующих сотрудников:
#                  index    values
# 0       share_of_promo  0.026251
# 1    mean_satisfaction  0.666810
# 2  mean_number_project  3.786664

# %% [markdown]
# #### 9. Разделить данные на тестовую и обучающую выборки. Построить модель LDA, предсказывающую уволился ли сотрудник на основе имеющихся факторов (кроме department и salary). Оценить качество модели на тестовой выборке.

# %%
del df['salary']
del df['department']
df
data_train, data_test = train_test_split(df, test_size=0.3)

# %%
data_train
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 2275                 0.94             0.74               5
# 11664                0.89             0.59               3
# 3665                 0.91             0.53               3
# 9640                 0.64             0.55               3
# 8937                 0.90             0.61               3
# ...                   ...              ...             ...
# 8686                 0.60             0.60               4
# 12500                0.91             0.84               5
# 9324                 0.57             0.66               4
# 8379                 0.69             0.61               2
# 4378                 0.85             0.55               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 2275                    171                   3              0     0
# 11664                   265                   8              0     0
# ...

# %%
data_test
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 6011                 0.56             0.76               3
# 14303                0.42             0.48               2
# 9601                 0.61             0.79               5
# 11856                0.81             0.92               4
# 11978                0.61             0.68               3
# ...                   ...              ...             ...
# 13314                0.77             0.81               4
# 10152                0.67             0.77               4
# 2018                 0.89             0.92               4
# 5369                 0.76             0.82               4
# 6689                 0.83             0.94               3
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 6011                    237                   3              0     0
# 14303                   143                   3              0     1
# ...

# %%
y_train, y_test = data_train['left'], data_test['left']
del data_train['left']
del data_test['left']

# %%
lda = LinearDiscriminantAnalysis()

# %%
lda.fit(data_train, y_train)
# Out:
# LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#                            solver='svd', store_covariance=False, tol=0.0001)

# %%
lda.predict(data_test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
result = pd.DataFrame([y_test.values, lda.predict(data_test)]).T

# %%
result
# Out:
#       0  1
# 0     0  0
# 1     1  0
# 2     0  0
# 3     0  0
# 4     0  0
# ...  .. ..
# 4495  0  0
# 4496  0  0
# 4497  0  0
# 4498  0  0
# 4499  0  0
#
# [4500 rows x 2 columns]

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, lda.predict(data_test))
# Out:
# 0.7657777777777778

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, lda.predict(data_test))
# Out:
# array([[3166,  278],
#        [ 776,  280]], dtype=int64)

# %% [markdown]
# ### Выводы
# Модель показала не самые лучшие результаты, в частности, точность прогнозирования составила 76,5%.
# Также следует выделить  матрицу неточностей: мы получили достаточно большое число ложно-отрицательных результатов (17,7%), т.е. модель определила реально уволенных сотрудников в действующие.
# Что касается ложно-положительных результатов, то их значительно меньше, чем ложно-отрицательных (5,7%), но результат тоже нельзя игнорировать или списать в статистическую погрешность.
# Также модель показала очень плохие результаты в определении уволенных сотрудников, все 24,0% реально уволенных сотрудников модель "угадала".
